# %% [markdown]
# # Grafica de mapas

# %%
import pandas as pd
import geopandas as gpd
import ipywidgets as widgets
import os
import matplotlib.pyplot as plt
import plotly.express as px
import warnings

# %% [markdown]
# Leemos datos de semaforos, poblacion CONAPO y geometrías.

# %%
data_path = './data'
tidy_path = data_path + '/tidy'
semaforo = pd.read_csv(tidy_path + '/delitos_semaforo.csv', encoding = 'iso-8859-1')
gdf = gpd.read_file('./data/conjunto_de_datos/areas_geoestadisticas_estatales.shp', 
                    columns = ["clave_entidad", 'nombre_entidad', 'geometry'])
poblacion = pd.read_excel('./data/0_Pob_Inicio_1950_2070.xlsx', sheet_name= 0,)

# %%
poblacion_2 = poblacion.groupby(['AÑO','ENTIDAD'])['POBLACION'].sum().reset_index()
poblacion_2 = poblacion_2[(poblacion_2['AÑO'] <= 2023) & (poblacion_2['AÑO'] >= 2015)]
poblacion_2 = poblacion_2[~(poblacion_2['ENTIDAD'] == 'República Mexicana' )]

# %% [markdown]
# ## Evolucion de poblacion 2015 - 2023

# %%
fig, ax = plt.subplots(1,1, figsize = (5,3))
ax.plot(poblacion_2.groupby('AÑO').sum().index,  poblacion_2.groupby('AÑO')["POBLACION"].sum().values);

# %% [markdown]
# Revizamos que los tres data frames tenga el mismo nombre para cada estado y cambiamos los necesarios

# %%
meses = semaforo.columns[10:22]

semaforo2 = semaforo.replace(to_replace = 'Veracruz de Ignacio de la Llave', value = 'Veracruz')\
    .groupby(['anio', 'entidad','delito_semaforo'])[meses].sum()\
    .sum(axis = 1)\
    .to_frame()\
    .reset_index()
    

semaforo2.rename(columns = {0:'incidentes'}, inplace = True)

# %% [markdown]
# Revizando que nombre de estados sean los mismos

# %%
gdf.replace({'Veracruz de Ignacio de la Llave':'Veracruz'}, inplace = True)
set(gdf['NOM_ENT']) == set(semaforo2['entidad'])
# Out:
# True

# %%
poblacion_2.ENTIDAD.replace({'Michoacán':'Michoacán de Ocampo','Coahuila':'Coahuila de Zaragoza'}, inplace = True)
set(semaforo2['entidad']) == set(poblacion_2.ENTIDAD)
# Out:
# True

# %% [markdown]
# Preparamos datos para graficar, haciendo merge sobre el nombre del estado

# %%
geometrias = pd.merge(poblacion_2, gdf, left_on = 'ENTIDAD', right_on = 'NOM_ENT', how = 'outer')\
    .drop(columns = ['CVE_ENT', 'NOM_ENT'])

geometrias = geometrias.merge(semaforo2, left_on = 'ENTIDAD', right_on = 'entidad', how = 'left')\
    .drop(columns  = ['AÑO', 'ENTIDAD'])\
    .rename(columns = {'POBLACION':'poblacion'})\
    [['anio', 'entidad', 'geometry', 'poblacion', 'delito_semaforo', 'incidentes']] #ordenar de una vez
geometrias['incidentes_per_10000_hab'] = 100000 * geometrias['incidentes'] / geometrias['poblacion']

#lo pasamos a geopandas porque se perdio
geometrias = gpd.GeoDataFrame(geometrias)
geometrias
# Out:
#        anio         entidad  \
# 0      2015  Aguascalientes
# 1      2015  Aguascalientes
# 2      2015  Aguascalientes
# 3      2015  Aguascalientes
# 4      2015  Aguascalientes
# ...     ...             ...
# 28507  2023       Zacatecas
# 28508  2023       Zacatecas
# 28509  2023       Zacatecas
# 28510  2023       Zacatecas
# 28511  2023       Zacatecas
#
#                                                 geometry  poblacion  \
# 0      POLYGON ((2470517.824 1155028.588, 2470552.248...    1332990
# 1      POLYGON ((2470517.824 1155028.588, 2470552.248...    1332990
# 2      POLYGON ((2470517.824 1155028.588, 2470552.248...    1332990
# 3      POLYGON ((2470517.824 1155028.588, 2470552.248...    1332990
# 4      POLYGON ((2470517.824 1155028.588, 2470552.248...    1332990
# ...                                                  ...        ...
# 28507  POLYGON ((2515182.307 1441549.749, 2515937.734...    1675298
# 28508  POLYGON ((2515182.307 1441549.749, 2515937.734...    1675298
# 28509  POLYGON ((2515182.307 1441549.749, 2515937.734...    1675298
# 28510  POLYGON ((2515182.307 1441549.749, 2515937.734...    1675298
# 28511  POLYGON ((2515182.307 1441549.749, 2515937.734...    1675298
#
#           delito_semaforo  incidentes  incidentes_per_10000_hab
# 0               Extorsión          39                  2.925753
# 1             Feminicidio           0                  0.000000
# 2              Homicidios          38                  2.850734
# 3                Lesiones        2289                171.719218
# 4            Narcomenudeo         614                 46.061861
# ...                   ...         ...                       ...
# 28507      Robo a negocio         227                 13.549828
# 28508     Robo a vehículo        1448                 86.432384
# 28509          Secuestros           5                  0.298454
# 28510           Violación         122                  7.282286
# 28511  Violencia familiar        2834                169.163934
#
# [28512 rows x 7 columns]

# %% [markdown]
# Grafica interactiva para vizualizar situacion actual de cada estado en contraste con los otros estados. Tomamos 3 categorias, la primera es para tasas menores al percentil 33, la segunda mayores al anterior y menores al percentil 66 y la ultima los datos que estan arriba del percentil 66.

# %%
warnings.filterwarnings("ignore")
def graficar_mapa(delito, año = 2022):
    fig, ax = plt.subplots(1,1, figsize = (10,10), dpi = 200)
    
    vista = geometrias[(geometrias['delito_semaforo'] == delito) & (geometrias['anio'] == año)]
    
    vista.plot(column = 'incidentes_per_10000_hab', 
               scheme = 'quantiles', 
               k = 3, 
               legend=True, 
               cmap='Reds', 
               ax = ax,
               edgecolor='black', 
               linewidth=0.3) 

    leg = ax.get_legend()
    leg.set_title("Incidentes cada 10,000 habitantes")
    ax.set_title(delito)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_facecolor('grey')
    

widgets.interact(graficar_mapa, delito = geometrias.delito_semaforo.unique(), año = range(2015, 2023));
# Out:
# interactive(children=(Dropdown(description='delito', options=('Extorsión', 'Feminicidio', 'Homicidios', 'Lesio…

# %%
#Un ejemplo de los mapas de arriba
fig, ax = plt.subplots(1,1, figsize = (10,10), dpi = 200)

vista = geometrias[(geometrias['delito_semaforo'] == 'Robo a casa') & (geometrias['anio'] == 2020)]

vista.plot(column = 'incidentes_per_10000_hab', 
           scheme = 'quantiles', 
           k = 3, 
           legend=True, 
           cmap='Reds', 
           ax = ax,
           edgecolor='black', 
           linewidth=0.3) 

leg = ax.get_legend()
leg.set_title("Incidentes cada 10,000 habitantes")
ax.set_title('Robo a casa')
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_facecolor('grey')
